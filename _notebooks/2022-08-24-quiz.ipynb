# %%
import getpass, sys

def question_with_response(prompt):
    print("Question: " + prompt)
    msg = input()
    return msg

def question_and_answer(prompt):
    print("Question: " + prompt)
    msg = input()
    print("Answer: " + msg)


questions = 6
correct = 0

print('Hello, ' + getpass.getuser() + " running " + sys.executable)
print("You will be asked " + str(questions) + " questions.")
question_and_answer("Are you ready to take a test?")

rsp = question_with_response("What is the name of the ship that brought the Pilgrims to America?")
if rsp == "Mayflower":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("What battle is considered the turning point of the American Revolution?")
if rsp == "Battle of Saratoga":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("What year was the Boston Massacre?")
if rsp == "1770":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

    rsp = question_with_response("Name the Founding Father who was the leader of the Sons of Liberty?")
if rsp == "Samuel Adams":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("Who was the first president to live in the White House?")
if rsp == "John Adams":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("Congress first established Independence Day as a holiday in what year?")
if rsp == "1870":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("Which of these three presidents died on the Fourth of July?")
if rsp == "John Adams, Thomas Jefferson and James Monroe":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("What political party formed in 1834 from anti-Andrew Jackson forces?")
if rsp == "Whig":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

print(getpass.getuser() + " you scored " + str(correct) +"/" + str(questions))
# Out:
# Hello, nguye running c:\Users\nguye\anaconda3\python.exe
# You will be asked 6 questions.
# Question: Are you ready to take a test?
# Answer: ye
# Question: What is the name of the ship that brought the Pilgrims to America?
# Mayflower is correct!
# Question: What battle is considered the turning point of the American Revolution?
# Mayflower is incorrect!
# Question: What year was the Boston Massacre?
# Battle of Saratoga is incorrect!
# Question: Name the Founding Father who was the leader of the Sons of Liberty?
# Samuel Adams is correct!
# Question: Who was the first president to live in the White House?
# Samuel Adams is incorrect!
# Question: Congress first established Independence Day as a holiday in what year?
# 1870 is correct!
# Question: Which of these three presidents died on the Fourth of July?
# John Adams, Thomas Jefferson and James Monroe is correct!
# Question: What political party formed in 1834 from anti-Andrew Jackson forces?
# Whig is correct!
# ...
